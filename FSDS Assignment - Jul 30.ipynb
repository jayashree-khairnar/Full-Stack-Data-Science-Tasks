# %% [markdown]
# #### 1. Find out the avarage rating on weekly basis keep this in a mind that they take two days of leave

# %% [markdown]
# ![Screen%20Shot%202022-08-12%20at%2009.25.27.png](attachment:Screen%20Shot%202022-08-12%20at%2009.25.27.png)

# %% [markdown]
# #### 2. Total working days for each agents

# %% [markdown]
# ![Screen%20Shot%202022-08-07%20at%2019.41.10.png](attachment:Screen%20Shot%202022-08-07%20at%2019.41.10.png)

# %% [markdown]
# #### 3. Total query that you have taken

# %% [markdown]
# ![Screen%20Shot%202022-08-07%20at%2019.42.21.png](attachment:Screen%20Shot%202022-08-07%20at%2019.42.21.png)

# %% [markdown]
# #### 4. Total Feedback that you have received

# %% [markdown]
# ![Screen%20Shot%202022-08-07%20at%2019.48.01.png](attachment:Screen%20Shot%202022-08-07%20at%2019.48.01.png)

# %% [markdown]
# #### 5. Agent name who have average rating between 3.5 to 4

# %% [markdown]
# ![Screen%20Shot%202022-08-08%20at%2011.56.33.png](attachment:Screen%20Shot%202022-08-08%20at%2011.56.33.png)

# %% [markdown]
# #### 6. Agent name who have rating less than 3.5

# %% [markdown]
# ![Screen%20Shot%202022-08-07%20at%2020.00.44.png](attachment:Screen%20Shot%202022-08-07%20at%2020.00.44.png)

# %% [markdown]
# #### 7. Agent name who have rating more than 4.5

# %% [markdown]
# ![Screen%20Shot%202022-08-07%20at%2020.03.42.png](attachment:Screen%20Shot%202022-08-07%20at%2020.03.42.png)

# %% [markdown]
# #### 8. How many agents have received feedback more than 4.5 average

# %% [markdown]
# ![Screen%20Shot%202022-08-07%20at%2020.08.17.png](attachment:Screen%20Shot%202022-08-07%20at%2020.08.17.png)

# %% [markdown]
# #### 9. Average weekly response time for each agent

# %% [markdown]
# ![Screen%20Shot%202022-08-08%20at%2011.51.05.png](attachment:Screen%20Shot%202022-08-08%20at%2011.51.05.png)

# %% [markdown]
# #### 10. Average weekly resolution time for each agents

# %% [markdown]
# ![Screen%20Shot%202022-08-08%20at%2011.53.45.png](attachment:Screen%20Shot%202022-08-08%20at%2011.53.45.png)

# %% [markdown]
# #### 11. List of all agents name

# %% [markdown]
# ![Screen%20Shot%202022-08-08%20at%2009.26.14.png](attachment:Screen%20Shot%202022-08-08%20at%2009.26.14.png)

# %% [markdown]
# #### 12. Percentage of chat on which they have received a feedback

# %% [markdown]
# ![Screen%20Shot%202022-08-08%20at%2012.08.30.png](attachment:Screen%20Shot%202022-08-08%20at%2012.08.30.png)

# %% [markdown]
# #### 13. Total contributation hour for each and every agents weekly basis

# %% [markdown]
# ![Screen%20Shot%202022-08-08%20at%2012.19.30.png](attachment:Screen%20Shot%202022-08-08%20at%2012.19.30.png)

# %% [markdown]
# #### 14. Total percentage of active hour for a month

# %% [markdown]
# ![Screen%20Shot%202022-08-08%20at%2012.43.08.png](attachment:Screen%20Shot%202022-08-08%20at%2012.43.08.png)
